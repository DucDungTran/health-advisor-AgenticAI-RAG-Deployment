# %%
import requests

query = {
  "prompt": "I'm a busy person who wants healthy, easy-to-make breakfasts. I like oatmeal and eggs. Please suggest two breakfast options, including their ingredients and calorie counts."
}

url = "http://localhost:9000/advise"

response = requests.post(url, json=query)

print(response.json()['output'])
# Out:
# Here are two healthy, easy-to-make breakfast options (growth-friendly for busy mornings). Each includes ingredients, calories, and estimated prices.
#
# 1) Overnight Oats Power Jar (2 servings)
# - Ingredients and calories
#   - Rolled oats, 1/2 cup: ~76 kcal per serving (total ~152 kcal)
#   - Plain Greek yogurt, 1/2 cup: ~33 kcal per serving (total ~66 kcal)
#   - Milk (dairy) or almond milk, 1/2 cup: ~38 kcal per serving (dairy) / ~10 kcal (almond)
#   - Berries, 1/2 cup: ~12 kcal per serving (total ~24 kcal)
#   - Chia seeds, 1 tablespoon: ~29 kcal per serving (total ~58 kcal)
#   - Honey or maple syrup, 1 teaspoon (optional): ~10 kcal per serving (total ~20 kcal)
# - Total calories (using dairy milk, no sweetener): ~188 kcal per serving; ~376 kcal total for the 2 servings
# - Estimated prices (per ingredient, approximate US ranges)
#   - Rolled oats (1/2 cup): ~$0.15
#   - Plain Greek yogurt (1/2 cup): ~$0.25
#   - Milk (1/2 cup, dairy): ~$0.25
#   - Berries (1/2 cup): ~$0.75
#   - Chia seeds (1 Tbsp): ~$0.15
#   - Honey/maple syrup (1 tsp, optional): ~$0.10
# - Note: Prices vary by store and region.
#
# 2) Spinach & Pepper Egg Muffin Cups (makes 6 muffins)
# - Ingredients and calories
#   - Eggs, 6: ~49 kcal per muffin (total ~294 kcal for 6)
#   - Fresh spinach, 1 cup: ~1 kcal per muffin (total ~6 kcal)
#   - Bell pepper, 1/2 cup: ~3 kcal per muffin (total ~18 kcal)
#   - Shredded cheese, 1/4 cup (optional): ~19 kcal per muffin (total ~114 kcal) [if included]
# - Total calories per muffin
#   - Without cheese: ~52 kcal each
#   - With cheese: ~71 kcal each
# - Estimated prices (per ingredient, approximate US ranges)
#   - Eggs (6): ~$0.60–$2.00 total for the batch (roughly $4–$5 per dozen nationally, varies by region)
#   - Spinach (1 cup): ~ $0.50
#   - Bell pepper (1/2 cup): ~ $0.50
#   - Shredded cheese (1/4 cup): ~ $0.50–$1.50
# - Note: Prices vary by store and region.
#
# Would you like me to lock these into a single, printable grocery list with exact per-serving costs based on your location (city/state) and preferred milk (dairy vs. plant-based)?
