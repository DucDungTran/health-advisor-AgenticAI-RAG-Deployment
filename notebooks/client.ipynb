# %%
import requests

query = {
  "prompt": "I'm a busy person who wants healthy, easy-to-make breakfasts. I like oatmeal and eggs. Please suggest two breakfast options, including their ingredients and calorie counts."
}

url = "http://127.0.0.1:8000/advise"

response = requests.post(url, json=query)

print(response.json()['output'])
# Out:
# Here are two healthy, easy breakfasts that fit your oats-and-eggs preference. Calories shown per ingredient and for the total meal. I’ll add estimated ingredient prices next.
#
# 1) Oatmeal Power Bowl
# - Quick oats (½ cup dry): 150 kcal
# - Mixed berries (½ cup): 40 kcal
# - Greek yogurt (¼ cup): 30 kcal
# - Chia seeds (1 tablespoon): 60 kcal
# - Total calories: 280 kcal
# - Estimated prices: [to be estimated by Price Checker Assistant]
#
# 2) Veggie Egg Muffin Bites
# - Eggs (2 large): 140 kcal
# - Spinach (½ cup, raw): 3 kcal
# - Bell pepper (¼ cup, raw): 3 kcal
# - Shredded cheddar cheese (¼ cup): 110 kcal
# - Total calories: 256 kcal
# - Estimated prices: [to be estimated by Price Checker Assistant]
#
# Would you like me to fetch current approximate prices for these ingredients now?
